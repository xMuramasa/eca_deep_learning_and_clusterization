# %%
# Generales
import pandas as pd
import numpy as np
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import pydot as pyd
import time
import joblib

# image preprocessing
import os
import sys
import shutil
import glob
import matplotlib.image as mpimg
from PIL import Image

#sklearn
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

#keras
import keras
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from keras.layers import Dropout, BatchNormalization

# keras utils
from keras.utils.vis_utils import model_to_dot
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import array_to_img, img_to_array, load_img
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from keras.utils.vis_utils import plot_model

#keras resnet_50_v2
from keras.applications.resnet_v2 import ResNet50V2
from keras.applications.resnet_v2 import preprocess_input

# tensorflow
import tensorflow as tf
from tensorflow.random import set_seed

#cv2
import cv2
from google.colab.patches import cv2_imshow

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %env name=samples1_512_equiv
# !echo $name
# Out:
# env: name=samples1_512_equiv
# samples1_512_equiv

# %%
# copy samples file to directory
# !cp ./drive/Shareddrives/Memoria/samples/$name.zip ./$name.zip

# !unzip -o -q $name.zip -d ./samples

# %%
set_seed(42)
np.random.seed(42)

# %%
# Constants

# dirs
inp_img_dir = "./samples/"
out_dir = ""

# init
start_num = 1

height, width = 32, 32

# placeholder
r = "rule_"

# all file names and classes
files = {'1':[], '2':[], '3':[], '4':[]}

# Classes
class1 = [0, 255,
        8, 64, 239, 253,
        32, 251,
        40, 96, 235, 249,
        128, 254,
        136, 192, 238, 252,
        160, 250,
        168, 224, 234, 248]

class2 = [1, 127,
        2, 16, 191, 247,
        3, 17, 63, 119,
        4, 223,
        5, 95,
        6, 20, 159, 215,
        7, 21, 31, 87,
        9, 65, 111, 125,
        10, 80, 175, 245,
        11, 47, 81, 117,
        12, 68, 207, 221,
        13, 69, 79, 93,
        14, 84, 143, 213,
        15, 85,
        19, 55,
        23,
        24, 66, 189, 231,
        25, 61, 67, 103,
        26, 82, 167, 181,
        27, 39, 53, 83,
        28, 70, 157, 199,
        29, 71,
        33, 123,
        34, 48, 187, 243,
        35, 49, 59, 115,
        36, 219,
        37, 91,
        38, 52, 155, 211,
        42, 112, 171, 241,
        43, 113,
        44, 100, 203, 217,
        46, 116, 139, 209,
        50, 179,
        51,
        56, 98, 185, 227,
        57, 99,
        58, 114, 163, 177,
        62, 118, 131, 145,
        72, 237,
        73, 109,
        74, 88, 173, 229,
        76, 205,
        77,
        78, 92, 141, 197,
        94, 133,
        104, 233,
        108, 201,
        130, 144, 190, 246,
        132, 222,
        134, 148, 158, 214,
        138, 174, 208, 224,
        140, 196, 206, 220,
        142, 212,
        152, 188, 194, 230,
        154, 166, 180, 210,
        156, 198,
        162, 176, 186, 242,
        164, 218,
        170, 240,
        172, 202, 216, 228,
        178,
        184, 226,
        200, 236,
        204,
        232]
class3 = [18, 183,
        22, 151,
        30, 86, 135, 149,
        45, 75, 89, 101,
        60, 102, 153, 195,
        90, 165,
        105,
        122, 161,
        126, 129,
        146, 182,
        150]
class4 = [41, 97, 107, 121,
        54, 147,
        106, 120, 169, 225,
        110, 124, 137, 193]

# %% [markdown]
# ## Dataset Generation

# %%
def getPics(classRules, samplesDir):
    classImgs = []

    for r in classRules:
        imgsDir = samplesDir + f'rule_{str(r)}/'
        classImgs += [imgsDir + f for f in os.listdir(imgsDir)]
    return classImgs


c1_img_list = getPics(class1, inp_img_dir)
c2_img_list = getPics(class2, inp_img_dir)
c3_img_list = getPics(class3, inp_img_dir)
c4_img_list = getPics(class4, inp_img_dir)

# %% [markdown]
# ## Data Prep

# %%
len(c1_img_list), len(c2_img_list), len(c3_img_list), len(c4_img_list)
# Out:
# (49388, 51199, 46576, 46573)

# %%
files_target = [np.full(len(c1_img_list), '1', dtype=str), 
         np.full(len(c2_img_list), '2', dtype=str), 
         np.full(len(c3_img_list), '3', dtype=str), 
         np.full(len(c4_img_list), '4', dtype=str), 
         ]
[x.shape[0] for x in files_target]
# Out:
# [49388, 51199, 46576, 46573]

# %%
# Data selection

c1_x = c1_img_list.copy()
c2_x = c2_img_list.copy()
c3_x = c3_img_list.copy()
c4_x = c4_img_list.copy()

c1_y = files_target[0].copy()
c2_y = files_target[1].copy()
c3_y = files_target[2].copy()
c4_y = files_target[3].copy()

# %%
c_x = np.array(c1_x+c2_x+c3_x+c4_x)
c_y = np.concatenate((c1_y,c2_y,c3_y,c4_y))

# %%
dataset = pd.DataFrame({'img':c_x, 'class':c_y})
dataset = dataset.sample(frac=1)[:100000]
dataset
# Out:
#                                              img class
# 6525      ./samples/rule_64/64_000_0241_8641.png     1
# 109900    ./samples/rule_86/86_000_0067_6984.png     3
# 20886   ./samples/rule_235/235_000_0163_8804.png     1
# 186640  ./samples/rule_124/124_000_0115_3527.png     4
# 3241    ./samples/rule_255/255_000_0232_4924.png     1
# ...                                          ...   ...
# 26271   ./samples/rule_128/128_000_0176_8599.png     1
# 177041  ./samples/rule_169/169_000_0024_6693.png     4
# 30010   ./samples/rule_136/136_000_0170_9488.png     1
# 102762  ./samples/rule_183/183_000_0125_5047.png     3
# 184953  ./samples/rule_124/124_000_0045_3300.png     4
#
# [100000 rows x 2 columns]

# %% [markdown]
# ## Data Split

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset['img'].values, dataset['class'].values, test_size=0.33, random_state=42)

# Reshape

y_train = y_train.reshape(-1, 1)
y_test = y_test.reshape(-1, 1)

# one hot encoding
enc = OneHotEncoder(sparse=False)
enc.fit(y_train)

# one hot encoding
joblib.dump(enc, './drive/Shareddrives/Memoria/encodings/encoder' + 'resnet_equiv_V2' + '.joblib')
enc.transform(y_train)

# transform data
y_train = enc.transform(y_train)

# print(pd.DataFrame(y_train, columns=list(enc.categories_[0])).head())

# tranform encoding for test data
y_test = enc.transform(y_test)
# to print the encoded features for train data
# print(pd.DataFrame(y_test, columns=list(enc.categories_[0])).head())
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
X_train[0], y_train[0]
# Out:
# ('./samples/rule_101/101_000_0046_4060.png', array([0., 0., 1., 0.]))

# %% [markdown]
# ## Images

# %%
def getImages(files):
    img_list = []

    for img in files:
        img1 = load_img(out_dir + img, color_mode='rgb')
        x = img_to_array(img1) / 255      
        
        img_list.append(x)

    return np.array(img_list)

# %%
# Images Preview
def imagePreview(imgsArr):
    imgs_show = [imgsArr[0], imgsArr[50], imgsArr[2589], imgsArr[-4]]
    plt.figure(figsize=(16,8))
    columns = 4
    
    for i, image in enumerate(imgs_show):
        plt.subplot(len(imgs_show) // columns + 1, columns, i + 1)
        
        plt.imshow(array_to_img(image))

    plt.figure()
    plt.show()

# %%
X_train = getImages(X_train)

# %%
imagePreview(X_train)

# %%
X_test = getImages(X_test)

imagePreview(X_test)

# %%
X_train[0].shape
# Out:
# (32, 32, 3)

# %% [markdown]
# ## Training

# %%
# parameters
kernel = 3
stride = 2

# input
input_shape = (height, width, 3)

res = ResNet50V2(weights='imagenet', input_shape=input_shape, include_top=False)
# Make all layers untrainable
for layer in res.layers[:]:
    layer.trainable = False

output = res.get_layer('conv3_block3_preact_bn').output
output = Flatten(name='new_flatten')(output)
output = Dense(1024, activation='relu', name='new_fc')(output)
output = Dense(4, activation='softmax')(output)
res = Model(res.input, output)


res.get_layer('new_fc').trainable = True
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 [==============================] - 1s 0us/step

# %%
# Model
save_dir = './drive/Shareddrives/Memoria/code/best_models/resnet_equiv_V2_best.h5'

# 1e-2
opt = Adam(learning_rate=1e-2, amsgrad=True)
met = tf.keras.metrics.CategoricalAccuracy()

res.compile(
    optimizer=opt,
    loss='categorical_crossentropy',
    metrics=[met]
)

checkpoint = tf.keras.callbacks.ModelCheckpoint(save_dir, 
                            monitor='val_categorical_accuracy', verbose=1, 
                            save_best_only=True, mode='max')

es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='max', verbose=1, patience=15)

callbacks_list = [checkpoint, es]

hist = res.fit(        
    x = X_train,
    y = y_train,
    validation_data=([X_test], y_test),
    # ep 50, b 12
    epochs=200,
    batch_size=12,
    verbose=1,
    callbacks=callbacks_list
)
# Out:
# Epoch 1/200
# 5584/5584 [==============================] - ETA: 0s - loss: 1.1523 - categorical_accuracy: 0.8807
# Epoch 1: val_categorical_accuracy improved from -inf to 0.80155, saving model to ./drive/Shareddrives/Memoria/code/best_models/resnet_equiv_V2_best.h5
# 5584/5584 [==============================] - 64s 10ms/step - loss: 1.1523 - categorical_accuracy: 0.8807 - val_loss: 0.5723 - val_categorical_accuracy: 0.8015
# Epoch 2/200
# 5578/5584 [============================>.] - ETA: 0s - loss: 0.3303 - categorical_accuracy: 0.9043
# Epoch 2: val_categorical_accuracy improved from 0.80155 to 0.94582, saving model to ./drive/Shareddrives/Memoria/code/best_models/resnet_equiv_V2_best.h5
# 5584/5584 [==============================] - 64s 12ms/step - loss: 0.3302 - categorical_accuracy: 0.9044 - val_loss: 0.2204 - val_categorical_accuracy: 0.9458
# Epoch 3/200
# 5583/5584 [============================>.] - ETA: 0s - loss: 0.2942 - categorical_accuracy: 0.9109
# Epoch 3: val_categorical_accuracy did not improve from 0.94582
# 5584/5584 [==============================] - 62s 11ms/step - loss: 0.2942 - categorical_accuracy: 0.9109 - val_loss: 0.5171 - val_categorical_accuracy: 0.7428
# Epoch 4/200
# 5580/5584 [============================>.] - ETA: 0s - loss: 0.5311 - categorical_accuracy: 0.8226
# Epoch 4: val_categorical_accuracy did not improve from 0.94582
# 5584/5584 [==============================] - 61s 11ms/step - loss: 0.5310 - categorical_accuracy: 0.8226 - val_loss: 0.4391 - val_categorical_accuracy: 0.8819
# Epoch 5/200
# 5580/5584 [============================>.] - ETA: 0s - loss: 0.4774 - categorical_accuracy: 0.8591
# Epoch 5: val_categorical_accuracy did not improve from 0.94582
# 5584/5584 [==============================] - 60s 11ms/step - loss: 0.4774 - categorical_accuracy: 0.8590 - val_loss: 0.3818 - val_categorical_accuracy: 0.8942
# Epoch 6/200
# 5583/5584 [============================>.] - ETA: 0s - loss: 0.4195 - categorical_accuracy: 0.8819
# Epoch 6: val_categorical_accuracy did not improve from 0.94582
# 5584/5584 [==============================] - 60s 11ms/step - loss: 0.4195 - categorical_accuracy: 0.8819 - val_loss: 0.5031 - val_categorical_accuracy: 0.7999
# Epoch 7/200
# 5584/5584 [==============================] - ETA: 0s - loss: 0.4260 - categorical_accuracy: 0.8845
# Epoch 7: val_categorical_accuracy did not improve from 0.94582
# 5584/5584 [==============================] - 61s 11ms/step - loss: 0.4260 - categorical_accuracy: 0.8845 - val_loss: 0.3987 - val_categorical_accuracy: 0.8715
# Epoch 8/200
# 5581/5584 [============================>.] - ETA: 0s - loss: 0.4364 - categorical_accuracy: 0.8861
# Epoch 8: val_categorical_accuracy did not improve from 0.94582
# 5584/5584 [==============================] - 60s 11ms/step - loss: 0.4364 - categorical_accuracy: 0.8861 - val_loss: 0.2805 - val_categorical_accuracy: 0.9382
# Epoch 9/200
# 5582/5584 [============================>.] - ETA: 0s - loss: 0.4103 - categorical_accuracy: 0.8943
# Epoch 9: val_categorical_accuracy did not improve from 0.94582
# 5584/5584 [==============================] - 61s 11ms/step - loss: 0.4102 - categorical_accuracy: 0.8944 - val_loss: 0.3702 - val_categorical_accuracy: 0.9009
# Epoch 10/200
# 5582/5584 [============================>.] - ETA: 0s - loss: 0.4942 - categorical_accuracy: 0.8661
# Epoch 10: val_categorical_accuracy did not improve from 0.94582
# 5584/5584 [==============================] - 60s 11ms/step - loss: 0.4944 - categorical_accuracy: 0.8660 - val_loss: 1.1369 - val_categorical_accuracy: 0.5022
# Epoch 11/200
# 5578/5584 [============================>.] - ETA: 0s - loss: 0.6344 - categorical_accuracy: 0.6758
# Epoch 11: val_categorical_accuracy did not improve from 0.94582
# 5584/5584 [==============================] - 60s 11ms/step - loss: 0.6343 - categorical_accuracy: 0.6759 - val_loss: 0.5433 - val_categorical_accuracy: 0.7353
# Epoch 12/200
# 5584/5584 [==============================] - ETA: 0s - loss: 0.5262 - categorical_accuracy: 0.7274
# Epoch 12: val_categorical_accuracy did not improve from 0.94582
# 5584/5584 [==============================] - 50s 9ms/step - loss: 0.5262 - categorical_accuracy: 0.7274 - val_loss: 0.5014 - val_categorical_accuracy: 0.7397
# Epoch 13/200
# 5577/5584 [============================>.] - ETA: 0s - loss: 0.5278 - categorical_accuracy: 0.7268
# Epoch 13: val_categorical_accuracy did not improve from 0.94582
# 5584/5584 [==============================] - 60s 11ms/step - loss: 0.5280 - categorical_accuracy: 0.7268 - val_loss: 0.4899 - val_categorical_accuracy: 0.7412
# Epoch 14/200
# 5584/5584 [==============================] - ETA: 0s - loss: 0.8414 - categorical_accuracy: 0.5493
# Epoch 14: val_categorical_accuracy did not improve from 0.94582
# 5584/5584 [==============================] - 51s 9ms/step - loss: 0.8414 - categorical_accuracy: 0.5493 - val_loss: 0.9058 - val_categorical_accuracy: 0.4922
# Epoch 15/200
# 5579/5584 [============================>.] - ETA: 0s - loss: 0.9042 - categorical_accuracy: 0.4979
# Epoch 15: val_categorical_accuracy did not improve from 0.94582
# 5584/5584 [==============================] - 50s 9ms/step - loss: 0.9043 - categorical_accuracy: 0.4978 - val_loss: 0.9177 - val_categorical_accuracy: 0.4896
# Epoch 16/200
# 5579/5584 [============================>.] - ETA: 0s - loss: 0.8750 - categorical_accuracy: 0.5201
# Epoch 16: val_categorical_accuracy did not improve from 0.94582
# 5584/5584 [==============================] - 62s 11ms/step - loss: 0.8746 - categorical_accuracy: 0.5203 - val_loss: 0.5973 - val_categorical_accuracy: 0.7390
# Epoch 17/200
# 5579/5584 [============================>.] - ETA: 0s - loss: 0.5485 - categorical_accuracy: 0.7218
# Epoch 17: val_categorical_accuracy did not improve from 0.94582
# 5584/5584 [==============================] - 50s 9ms/step - loss: 0.5485 - categorical_accuracy: 0.7218 - val_loss: 0.4739 - val_categorical_accuracy: 0.7265
# Epoch 18/200
# 5581/5584 [============================>.] - ETA: 0s - loss: 0.5276 - categorical_accuracy: 0.7289
# Epoch 18: val_categorical_accuracy did not improve from 0.94582
# 5584/5584 [==============================] - 52s 9ms/step - loss: 0.5276 - categorical_accuracy: 0.7289 - val_loss: 0.5113 - val_categorical_accuracy: 0.7421
# Epoch 19/200
# 5582/5584 [============================>.] - ETA: 0s - loss: 0.5421 - categorical_accuracy: 0.7274
# Epoch 19: val_categorical_accuracy did not improve from 0.94582
# 5584/5584 [==============================] - 51s 9ms/step - loss: 0.5420 - categorical_accuracy: 0.7274 - val_loss: 0.5055 - val_categorical_accuracy: 0.7403
# Epoch 20/200
# 5580/5584 [============================>.] - ETA: 0s - loss: 0.5137 - categorical_accuracy: 0.7330
# Epoch 20: val_categorical_accuracy did not improve from 0.94582
# 5584/5584 [==============================] - 50s 9ms/step - loss: 0.5137 - categorical_accuracy: 0.7330 - val_loss: 0.5125 - val_categorical_accuracy: 0.7414
# Epoch 21/200
# 5578/5584 [============================>.] - ETA: 0s - loss: 0.5297 - categorical_accuracy: 0.7301
# Epoch 21: val_categorical_accuracy did not improve from 0.94582
# 5584/5584 [==============================] - 51s 9ms/step - loss: 0.5296 - categorical_accuracy: 0.7301 - val_loss: 0.5327 - val_categorical_accuracy: 0.7388
# Epoch 22/200
# 5581/5584 [============================>.] - ETA: 0s - loss: 0.5199 - categorical_accuracy: 0.7295
# Epoch 22: val_categorical_accuracy did not improve from 0.94582
# 5584/5584 [==============================] - 60s 11ms/step - loss: 0.5199 - categorical_accuracy: 0.7295 - val_loss: 0.5820 - val_categorical_accuracy: 0.7428
# Epoch 23/200
# 5581/5584 [============================>.] - ETA: 0s - loss: 0.5209 - categorical_accuracy: 0.7329
# Epoch 23: val_categorical_accuracy did not improve from 0.94582
# 5584/5584 [==============================] - 51s 9ms/step - loss: 0.5208 - categorical_accuracy: 0.7329 - val_loss: 0.4709 - val_categorical_accuracy: 0.7252
# Epoch 24/200
# 5584/5584 [==============================] - ETA: 0s - loss: 0.6105 - categorical_accuracy: 0.6989
# Epoch 24: val_categorical_accuracy did not improve from 0.94582
# 5584/5584 [==============================] - 61s 11ms/step - loss: 0.6105 - categorical_accuracy: 0.6989 - val_loss: 0.8503 - val_categorical_accuracy: 0.4050
# Epoch 25/200
# 5577/5584 [============================>.] - ETA: 0s - loss: 0.7405 - categorical_accuracy: 0.6438
# Epoch 25: val_categorical_accuracy did not improve from 0.94582
# 5584/5584 [==============================] - 60s 11ms/step - loss: 0.7404 - categorical_accuracy: 0.6439 - val_loss: 0.7211 - val_categorical_accuracy: 0.6634
# Epoch 25: early stopping

# %%
fig = plt.figure(figsize=(18, 7), facecolor='w', edgecolor='k')
gs  = gridspec.GridSpec(nrows=1, ncols=2)
ax = plt.subplot(gs[0, 0]), plt.subplot(gs[0, 1])

colors_list = ["crimson", "orchid", "navy", "aqua"]

num=2
l1 = ax[0].plot(hist.history['loss'], c=colors_list[num] ,label='Model '+str(num)+': Train ', linewidth=2)
ax[0].plot(hist.history['val_loss'], ls='dotted', c=colors_list[0], label='Model '+str(num)+': Val', linewidth=2)

ax[1].plot(hist.history['categorical_accuracy'], c=l1[0].get_color(), linewidth=2)
ax[1].plot(hist.history['val_categorical_accuracy'], ls='dotted', c=colors_list[0], linewidth=2)

# labels
ax[0].set_title('Loss')
ax[0].set_xlabel('Epoch')
ax[0].set_xlim([0, 50])
ax[1].set_title('Accuracy')
ax[1].set_xlabel('Epoch')
ax[1].set_xlim([0, 50])

handles, labels = ax[0].get_legend_handles_labels()
plt.legend(labels, loc="best", bbox_to_anchor=(0, 1.15))
plt.show()
