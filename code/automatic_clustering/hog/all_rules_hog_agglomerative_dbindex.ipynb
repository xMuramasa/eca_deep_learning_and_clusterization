# %%
# Generales
import pandas as pd
import numpy as np
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import pydot as pyd
import time
import joblib

# image preprocessing
import os
import sys
import shutil
import glob
import matplotlib.image as mpimg
from PIL import Image

# clustimage
from clustimage import Clustimage

from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score, jaccard_score,\
                            f1_score, precision_recall_curve,\
                            confusion_matrix, ConfusionMatrixDisplay,\
                            silhouette_score, mutual_info_score

# My packages
from tools import show_results_frecuencies as show_results

# %%
# Constants

# dirs
inp_img_dir = "./samples/"
out_dir = ""

# init
start_num = 1

height, width = 32, 32

# placeholder
r = "rule_"

# Classes
class1 = [0, 255,
        8, 64, 239, 253,
        32, 251,
        40, 96, 235, 249,
        128, 254,
        136, 192, 238, 252,
        160, 250,
        168, 224, 234, 248]

class2 = [1, 127,
        2, 16, 191, 247,
        3, 17, 63, 119,
        4, 223,
        5, 95,
        6, 20, 159, 215,
        7, 21, 31, 87,
        9, 65, 111, 125,
        10, 80, 175, 245,
        11, 47, 81, 117,
        12, 68, 207, 221,
        13, 69, 79, 93,
        14, 84, 143, 213,
        15, 85,
        19, 55,
        23,
        24, 66, 189, 231,
        25, 61, 67, 103,
        26, 82, 167, 181,
        27, 39, 53, 83,
        28, 70, 157, 199,
        29, 71,
        33, 123,
        34, 48, 187, 243,
        35, 49, 59, 115,
        36, 219,
        37, 91,
        38, 52, 155, 211,
        42, 112, 171, 241,
        43, 113,
        44, 100, 203, 217,
        46, 116, 139, 209,
        50, 179,
        51,
        56, 98, 185, 227,
        57, 99,
        58, 114, 163, 177,
        62, 118, 131, 145,
        72, 237,
        73, 109,
        74, 88, 173, 229,
        76, 205,
        77,
        78, 92, 141, 197,
        94, 133,
        104, 233,
        108, 201,
        130, 144, 190, 246,
        132, 222,
        134, 148, 158, 214,
        138, 174, 208, 224,
        140, 196, 206, 220,
        142, 212,
        152, 188, 194, 230,
        154, 166, 180, 210,
        156, 198,
        162, 176, 186, 242,
        164, 218,
        170, 240,
        172, 202, 216, 228,
        178,
        184, 226,
        200, 236,
        204,
        232]
class3 = [18, 183,
        22, 151,
        30, 86, 135, 149,
        45, 75, 89, 101,
        60, 102, 153, 195,
        90, 165,
        105,
        122, 161,
        126, 129,
        146, 182,
        150]
class4 = [41, 97, 107, 121,
        54, 147,
        106, 120, 169, 225,
        110, 124, 137, 193]

# %% [markdown]
# total images per class
# - c1: 49364
# - c2: 51007
# - c3: 46550
# - c4: 46559

# %%
1250/len(class1), 1250/len(class2), 1250/len(class3), 1250/len(class4)
# Out:
# (52.083333333333336, 6.510416666666667, 48.07692307692308, 89.28571428571429)

# %%
def getPics(class_rules, samples_dir, n_samples_per_rule=None):
    class_imgs = []

    for r in class_rules:
        imgs_dir = samples_dir + f'rule_{str(r)}/'
        imgs_temp = [imgs_dir + f for f in os.listdir(imgs_dir)]
        class_imgs += imgs_temp[:n_samples_per_rule] # class balancing
    return class_imgs

c1_img_list = getPics(class1, inp_img_dir, 52)
c2_img_list = getPics(class2, inp_img_dir, 6)
c3_img_list = getPics(class3, inp_img_dir, 48)
c4_img_list = getPics(class4, inp_img_dir, 89)

# %%
files_target = [np.full(len(c1_img_list), 1), 
                np.full(len(c2_img_list), 2), 
                np.full(len(c3_img_list), 3), 
                np.full(len(c4_img_list), 4)]
[x.shape[0] for x in files_target]
# Out:
# [1248, 1152, 1248, 1246]

# %%
# Data selection

c1_x = c1_img_list.copy()
c2_x = c2_img_list.copy()
c3_x = c3_img_list.copy()
c4_x = c4_img_list.copy()

c1_y = files_target[0].copy()
c2_y = files_target[1].copy()
c3_y = files_target[2].copy()
c4_y = files_target[3].copy()

c_x = np.array(c1_x+c2_x+c3_x+c4_x)
c_y = np.concatenate((c1_y,c2_y,c3_y,c4_y))

# %%
dataset = pd.DataFrame({'img':c_x, 'class':c_y})
dataset = dataset.sample(frac=1)
print(dataset.shape)
dataset.head(3)
# Out:
# (4894, 2)
#                                            img  class
# 3928  ./samples/rule_121/121_000_0158_7862.png      4
# 1316  ./samples/rule_223/223_000_0198_7304.png      2
# 1287      ./samples/rule_3/3_000_0049_6831.png      2

# %%
# Assert total representation of classes
dataset.img.apply(lambda x: x.split('/')[2]).nunique()
# Out:
# 255

# %%
dataset.hist(figsize=(6,3))
plt.show()

# %%
cl = Clustimage(method='hog',
                    params_hog={'orientations':8,
                                'pixels_per_cell':(8,8),
                                'cells_per_block':(1,1)})
# Out:
# [clustimage] >WARNING> Parameter grayscale is set to True coz you are using method="hog"
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]

# %%
# clustimage object parameters

cluster='agglomerative'
evaluate='dbindex'
metric='euclidean'
linkage='ward'
min_clust=3
max_clust=6
cluster_space='low'

# %%
results = cl.fit_transform(dataset['img'].values,
                           cluster=cluster,
                           evaluate=evaluate,
                           metric=metric,
                           linkage=linkage,
                           min_clust=min_clust,
                           max_clust=max_clust,
                           cluster_space=cluster_space)
# Out:
# [clustimage] >INFO> Cleaning previous fitted model results
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# 100%|██████████| 4894/4894 [00:02<00:00, 1762.86it/s]
# [clustimage] >INFO> Extracting features using method: [hog]
# 100%|██████████| 4894/4894 [15:47<00:00,  5.16it/s]
# [clustimage] >INFO> Extracted features using [hog]: samples=4894, features=65536
# [clustimage] >INFO> Compute [tsne] embedding
# [clustimage] >INFO> Cluster evaluation using the [low] feature space of the [tsne] coordinates.
# [clusteval] >Fit using agglomerative with metric: euclidean, and linkage: ward
# [clusteval] >Evaluate using dbindex.
# 100%|██████████| 3/3 [00:00<00:00, 23.08it/s]
# [clustimage] >INFO> Updating cluster-labels and cluster-model based on the (4894, 2) feature-space.
# [clusteval] >Compute dendrogram threshold.
# [clusteval] >Optimal number clusters detected: [5].
# [clusteval] >Fin.

# %%
# Silhouette plots
cl.clusteval.plot(figsize=(6,3))
# Out:
# (<Figure size 600x300 with 1 Axes>,
#  <Axes: title={'center': 'Davies Bouldin index vs. nr.clusters'}, xlabel='#Clusters', ylabel='Score'>)

# %%
cl.clusteval.scatter(cl.results['xycoord'], figsize=(6,3))
# Out:
# [clusteval] >Estimated number of n_clusters: 5, average silhouette_score=0.509
# (<Figure size 1800x700 with 2 Axes>,
#  <Axes: title={'center': 'The silhouette plot for the various clusters'}, xlabel='The silhouette coefficient values', ylabel='Cluster label'>,
#  <Axes: title={'center': 'Estimated cluster labels'}, xlabel='1st feature', ylabel='2nd feature'>)

# %%
# Plot unique image per cluster
cl.plot_unique(img_mean=False, figsize=(6,6))

# %%
# Plot unique image per cluster
cl.plot_unique(figsize=(6,6))

# %%
# Scatterplot
cl.scatter(zoom=0.4, img_mean=False, figsize=(10,6))
# Out:
# (<Figure size 1000x600 with 1 Axes>,
#  <Axes: title={'center': 'tsne plot. Samples are coloured on the cluster labels (low dimensional).'}, xlabel='x-axis', ylabel='y-axis'>)

# %% [markdown]
# # Results

# %%
names, labels = cl.results['pathnames'],\
                cl.results['labels']

results_df = pd.DataFrame(data={'img':names,
                                'y_pred':labels})
results_df.head(3)
# Out:
#                                         img  y_pred
# 0  ./samples/rule_121/121_000_0158_7862.png       2
# 1  ./samples/rule_223/223_000_0198_7304.png       4
# 2      ./samples/rule_3/3_000_0049_6831.png       2

# %%
save_path = './results/'

file_name = f'all_imgs_{cluster}_{evaluate}_{metric}.csv'

results_df.to_csv(save_path + file_name, index=False)

# %%
np.unique(c_y), np.unique(labels)
# Out:
# (array([1, 2, 3, 4]), array([0, 1, 2, 3, 4], dtype=int32))

# %%
scores = {
    'accuracy_score' : {
        'results': accuracy_score(c_y, labels)
    },
    'jaccard_score':{
        'results':jaccard_score(c_y, labels, average="micro")
    },
    'f1_score':{
        'results': f1_score(c_y, labels, average='micro')
    },
    'mutual_info_score':{
        'results': mutual_info_score(c_y, labels)
    },
    
}

results_df = pd.DataFrame.from_dict(scores)
results_df.T
# Out:
#                     results
# accuracy_score     0.174499
# jaccard_score      0.095590
# f1_score           0.174499
# mutual_info_score  0.001113

# %%
n_classes = len(np.unique(labels))
show_results(labels, n_classes, 'y_train', 10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="e0e8d245-6615-49b2-9a76-565a01f4c301" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0e8d245-6615-49b2-9a76-565a01f4c301")) {                    Plotly.newPlot(                        "e0e8d245-6615-49b2-9a76-565a01f4c301",                        [{"marker":{"color":["rgb(93, 164, 214)","rgb(255, 144, 14)","rgb(44, 160, 101)","rgb(255, 65, 54)"],"size":[127.9,50.9,105.9,127.2,77.5]},"mode":"markers","text":["Class 0<br />items: 1279","Class 1<br />items: 509","Class 2<br />items: 1059","Class 3<br />items: 1272","Class 4<br />items: 775"],"x":[0,1,2,3,4],"y":[10,10,10,10,10],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatte ...
